# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df=pd.read_csv(r"C:\Users\tejas\Downloads\StudentsPerformance(1)(1).csv")   #location of file

# %%
plt.figure(figsize=(60,20))
plt.subplots_adjust(left=0.125,bottom=0.1,right=0.5,top=0.9,wspace=0.5,hspace=0.2)

plt.subplot(251)
plt.title("grades and gender")
sns.countplot(hue="gender" , x="race/ethnicity", data=df)
print(plt.savefig("G:\w1.pdf"))

plt.subplot(252)
plt.title("grades and gender")
sns.countplot(hue="lunch",x="race/ethnicity",data=df)
print(plt.savefig("G:\w2.pdf"))

plt.subplot(253)
plt.title("grades and test preparation course")
sns.countplot(hue="test preparation course",x="race/ethnicity",data=df)
print(plt.savefig("G:\w3.pdf"))
# Out:
# None
# None
# None

# %%
plt.rcParams['figure.figsize']=(20,10)
sns.countplot(df['math score' ],palette="dark")
plt.title("math score",fontsize=20)
plt.show()
print(plt.savefig("G:\w4.pdf"))
# Out:
# None
